# %% [markdown]
# ## A. Mengimpor _package_ yang diperlukan

# %%
import pandas as pd

# %% [markdown]
# ## B. Mengeksplorasi isi data

# %% [markdown]
# #### 1. Melihat dataframe

# %%
df = pd.read_csv('covid_19_data.csv')
df
# Out:
#          SNo ObservationDate Province/State  Country/Region  \
# 0          1      01/22/2020          Anhui  Mainland China
# 1          2      01/22/2020        Beijing  Mainland China
# 2          3      01/22/2020      Chongqing  Mainland China
# 3          4      01/22/2020         Fujian  Mainland China
# 4          5      01/22/2020          Gansu  Mainland China
# ...      ...             ...            ...             ...
# 16724  16725      04/19/2020        Wyoming              US
# 16725  16726      04/19/2020       Xinjiang  Mainland China
# 16726  16727      04/19/2020          Yukon          Canada
# 16727  16728      04/19/2020         Yunnan  Mainland China
# 16728  16729      04/19/2020       Zhejiang  Mainland China
#
#                Last Update  Confirmed  Deaths  Recovered
# 0          1/22/2020 17:00        1.0     0.0        0.0
# 1          1/22/2020 17:00       14.0     0.0        0.0
# 2          1/22/2020 17:00        6.0     0.0        0.0
# ...

# %% [markdown]
# #### 2. Mengecek data null

# %%
df.isna().sum()
# Out:
# SNo                   0
# ObservationDate       0
# Province/State     8372
# Country/Region        0
# Last Update           0
# Confirmed             0
# Deaths                0
# Recovered             0
# dtype: int64

# %% [markdown]
# #### 3. Melihat tipe data setiap kolom

# %%
df.dtypes
# Out:
# SNo                  int64
# ObservationDate     object
# Province/State      object
# Country/Region      object
# Last Update         object
# Confirmed          float64
# Deaths             float64
# Recovered          float64
# dtype: object

# %% [markdown]
# ## C. Konversi susunan kolom

# %% [markdown]
# #### 1. Mengkonversi susunan kolom _Confirmed_, _Cases_, dan _Recovered_ agar hanya menjadi 1 kolom

# %%
df = df.melt(id_vars=['SNo', 'ObservationDate', 'Province/State', 'Country/Region', 'Last Update'], 
        var_name="Cases", 
        value_name="Counted")
df
# Out:
#          SNo ObservationDate Province/State  Country/Region  \
# 0          1      01/22/2020          Anhui  Mainland China
# 1          2      01/22/2020        Beijing  Mainland China
# 2          3      01/22/2020      Chongqing  Mainland China
# 3          4      01/22/2020         Fujian  Mainland China
# 4          5      01/22/2020          Gansu  Mainland China
# ...      ...             ...            ...             ...
# 50182  16725      04/19/2020        Wyoming              US
# 50183  16726      04/19/2020       Xinjiang  Mainland China
# 50184  16727      04/19/2020          Yukon          Canada
# 50185  16728      04/19/2020         Yunnan  Mainland China
# 50186  16729      04/19/2020       Zhejiang  Mainland China
#
#                Last Update      Cases  Counted
# 0          1/22/2020 17:00  Confirmed      1.0
# 1          1/22/2020 17:00  Confirmed     14.0
# 2          1/22/2020 17:00  Confirmed      6.0
# 3          1/22/2020 17:00  Confirmed      1.0
# ...

# %% [markdown]
# #### 2. Menyimpan dataframe ke file csv

# %%
df.to_csv('covid_19_melted.csv', index=False)
